# %% [markdown]
# QUESTION 1
#
# Flask is a web framework, it’s a Python module that lets you develop web applications easily.
# ADVANTAGES-
# 1.It is suitable for small projects.
# 2.Easily scalable for the applications.
# 3.Flask is compatible with the latest technologies such as machine learning, agile development, cloud technologies, etc.

# %% [markdown]
# QUESTION 2
#
# ![image.png](attachment:6137c178-7f7a-404c-9bdb-5a1d4fec1cde.png)

# %% [markdown]
# QUESION 3
#
# App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.
# The route() decorator, @app.route(), binds a URL to a function.

# %% [markdown]
# QUESTION 4
#
# CODE:-
#
# from flask import Flask
#
# assn = Flask(__name__)
#
# @assn.route("/welcome")
# def welcome():
#     return "<h1>""Welcome to ABC Corporation""</h1>"
#
# if __name__=="__main__":
#     assn.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:7a70050b-09a3-4aaf-afa7-75400d69cd4b.png)

# %% [markdown]
# ![image.png](attachment:437c5cc3-840b-46ab-9bda-1ff60434b625.png)

# %%
QUESTION 5

The url_for() function is used to build a URL to the specific function dynamically.
